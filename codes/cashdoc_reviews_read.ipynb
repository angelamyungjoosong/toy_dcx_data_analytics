# %%
import pandas as pd

# %%
df_cashdoc = pd.read_csv("../dataset/toy_dcx_data_analytics.cashdoc_reviews.csv")
df_cashdoc
# Out:
#                            _id               post_title post_nickname  \
# 0     65041fa90a9ef7b4120e4bec             경주 허리 잘보는 병원         용용이02
# 1     65041fa90a9ef7b4120e4bed                허리 치료 방법?           큰사람
# 2     65041fa90a9ef7b4120e4bee           목디스크로 팔이 저려요 ㅠ         스위트10
# 3     65041fa90a9ef7b4120e4bef               추나요법 궁금합니다           정미영
# 4     65041fa90a9ef7b4120e4bf0            허리디스크 침치료 문의요           정정우
# ...                        ...                      ...           ...
# 9016  6504216f4cda772b3293aa87                   턱디스크..            수연
# 9017  6504216f4cda772b3293aa88  하루20분 요가로 오십견 목디스크 해결하기           이헌우
# 9018  6504216f4cda772b3293aa89                   제 건강목표          털미미네
# 9019  6504216f4cda772b3293aa8a               다리 통증 및 저림           신정호
# 9020  6504216f4cda772b3293aa8b                 (고민)허리통증         solye
#
#              post_date                                       post_content  \
# ...

# %%
df_cashdoc_drop = df_cashdoc.drop(columns =['_id'])
df_cashdoc_drop
# Out:
#                    post_title post_nickname         post_date  \
# 0                경주 허리 잘보는 병원         용용이02  2023.08.08 22:44
# 1                   허리 치료 방법?           큰사람  2023.08.07 23:55
# 2              목디스크로 팔이 저려요 ㅠ         스위트10  2023.08.07 23:38
# 3                  추나요법 궁금합니다           정미영  2023.08.07 23:27
# 4               허리디스크 침치료 문의요           정정우  2023.08.07 23:12
# ...                       ...           ...               ...
# 9016                   턱디스크..            수연  2023.06.20 23:08
# 9017  하루20분 요가로 오십견 목디스크 해결하기           이헌우  2023.06.20 22:20
# 9018                   제 건강목표          털미미네  2023.06.20 19:54
# 9019               다리 통증 및 저림           신정호  2023.06.20 16:37
# 9020                 (고민)허리통증         solye  2023.06.19 21:24
#
#                                            post_content comment_nickname  \
# 0             허리(디스크)잘 보는 병원 있을까요\n물리치료까지 잘봐주시는곳 추천해주세요              저스틴
# ...

# %%
df_cashdoc_drop_drop = df_cashdoc_drop.drop_duplicates()
df_cashdoc_drop_drop
# Out:
#                    post_title post_nickname         post_date  \
# 0                경주 허리 잘보는 병원         용용이02  2023.08.08 22:44
# 1                   허리 치료 방법?           큰사람  2023.08.07 23:55
# 2              목디스크로 팔이 저려요 ㅠ         스위트10  2023.08.07 23:38
# 3                  추나요법 궁금합니다           정미영  2023.08.07 23:27
# 4               허리디스크 침치료 문의요           정정우  2023.08.07 23:12
# ...                       ...           ...               ...
# 8494                   턱디스크..            수연  2023.06.20 23:08
# 8624  하루20분 요가로 오십견 목디스크 해결하기           이헌우  2023.06.20 22:20
# 8755                   제 건강목표          털미미네  2023.06.20 19:54
# 8887               다리 통증 및 저림           신정호  2023.06.20 16:37
# 9020                 (고민)허리통증         solye  2023.06.19 21:24
#
#                                            post_content comment_nickname  \
# 0             허리(디스크)잘 보는 병원 있을까요\n물리치료까지 잘봐주시는곳 추천해주세요              저스틴
# ...

# %%
df_cashdoc_drop_drop.to_csv("../dataset/toy_dcx_data_analytics.cashdoc_reviews_drop.csv")
